# %%
from DrissionPage import ChromiumPage, ChromiumOptions
import time
import pandas as pd
import random

# %%
def extract_paper_details(result: ChromiumPage) -> dict:
    """
    Extracts details from a single arXiv paper result.
    Args:
        result (DrissionPage): The DrissionPage object representing the paper result.
    Returns:    
        dict: A dictionary containing the extracted details.
    """
    
    try:
        # Extract arXiv paper link
        link_element = result.ele('css:a[href*="abs"]')
        link = link_element.link if link_element else None

        # Extract pdf link
        pdf_link_element = result.ele('css:a[href*="pdf"]')
        pdf_link = pdf_link_element.link if pdf_link_element else None

        # Extract title
        title_element = result.ele('css:p.title')
        title = title_element.text.strip() if title_element else None

        # Extract authors
        authors_element = result.ele('css:p.authors')
        authors = authors_element.text.replace("Authors:", "").strip() if authors_element else None

        # Extract abstract
        abstract_element = result.ele('css:p.abstract span.abstract-full')
        abstract = abstract_element.text.strip() if abstract_element else None
        if abstract and "△ Less" in abstract:
            abstract = abstract.split("△ Less")[0].strip()

        # Extract submitted date
        submitted_element = result.ele('css:p.is-size-7')
        submitted = submitted_element.text.strip() if submitted_element else None

    except Exception as e:
        print(f"Error extracting details: {e}")

    return {
        'link': link,
        'pdf_link': pdf_link,
        'title': title,
        'authors': authors,
        'abstract': abstract,
        'submitted': submitted
    }

# %%
def paper_crawl(keywords: str) -> list:
    """
    Crawls arXiv for papers based on the given keywords.
    Args:
        keywords (str): The keywords to search for.     
    Returns:
        list: A list of dictionaries containing paper details.
    """

    #List of paper data
    papers_data = []

    # Navigate to the search page
    # Construct the search URL
    search_url = f'https://arxiv.org/search/?query={keywords}&searchtype=all&source=header&abstracts=show'
    print(search_url)
    
    option = ChromiumOptions()
    # Uncomment the following lines to run in headless mode or with specific options
    option.headless(on_off=True)  # Run in headless mode
    # Initialize the page
    page = ChromiumPage(addr_or_opts=option)
    try:
        page.get(search_url)
        cnt = 1
        while True:
            # Wait for the page to load fully
            page.scroll.to_bottom()
            time.sleep(random.randint(2,3))
            
            print(f"Page {cnt} loaded, extracting data...")

            # Target the result element
            arxiv_results = page.eles ('css:li.arxiv-result')

            # Loop through each result and extract details
            for result in arxiv_results:
                paper_data = {}
                try:
                    paper_data = extract_paper_details(result)
                    papers_data.append(paper_data)
                except Exception as e:
                    print(f"Error extracting data from a result: {e}")

            # Check if the "Load More" button is present
            next_button = page.ele('css:a.pagination-next')
            if next_button and 'is-invisible' not in next_button.attr('class'):
                next_button.click()
                cnt += 1
                print(f"Loading next page...")
            else:
                print("No more pages to load.")
                break

    except Exception as e:
        print(f"Error: {e}")
    
    finally:
        page.quit()
        return papers_data

# %%
def save_to_csv(data: list, filename: str) -> None:
    """
    Save the extracted data to a CSV file.
    """
    try:
        df = pd.DataFrame(data)
        df.drop_duplicates(subset=['link'], inplace=True)
        df.to_csv(f'arxiv/{filename}', index=False)
        print(f"Data saved to {filename}")
    except Exception as e:
        print(f"Error saving data to CSV: {e}")

# %%
import itertools

def combination_keywords(sets):
    """Tạo danh sách các chuỗi từ khóa từ một danh sách các bộ từ khóa."""
    if not sets:
        return []
    combinations = itertools.product(*sets)
    return [' AND '.join(combo) for combo in combinations]

def generate_all_combinations(t2sql, security, llm):
    """Tạo danh sách tất cả các tổ hợp từ khóa theo các trường hợp yêu cầu."""
    # Định nghĩa các trường hợp cần tạo tổ hợp
    cases = [
        [t2sql],                    # Chỉ t2sql
        [t2sql, security],          # t2sql + security
        [t2sql, llm],               # t2sql + llm
        [t2sql, security, llm]      # t2sql + security + llm
    ]
    
    # Tạo và hợp nhất tất cả các tổ hợp
    all_combinations = []
    for case in cases:
        all_combinations.extend(combination_keywords(case))
    
    return all_combinations

# %%
def crawl_arxiv():
    """
    Main function to run the pipeline.
    """
    
    t2sql = ['"text-to-sql"', '"nl2sql"', '"t2sql"', '"text2sql"', '"natural language to sql"', 
             '"semantic parsing to sql"', '"nl to sql"']
    security = ['"security"', '"access control"', '"injection"', '"prompt injection"', '"defense"', '"attack"', '"vulnerability"']
    llm = ['"llm"', '"large language model"']

    keywords = generate_all_combinations(t2sql, security, llm)

    tmp = []

    # Crawl papers
    for keyword in keywords:
        print(f"Searching for papers related to: {keyword}")
        keyword_1 = keyword.strip()
        keyword_1 = keyword_1.replace(" ", "+")
        papers_data = paper_crawl(keyword_1)
        if len(papers_data) > 0:
            keyword = keyword.replace('"', '')
            keyword = keyword.replace(' ', '_')
            save_to_csv(papers_data,f"crawl_by_{keyword}.csv")
        tmp.extend(papers_data)

    if tmp:
        # Save data to CSV
        filename = "all_arxiv_papers"
        save_to_csv(tmp, f"{filename}.csv")
        print(f"Extracted {len(tmp)} papers.")

# %%
crawl_arxiv()
# Out:
# Searching for papers related to: "text-to-sql"
# https://arxiv.org/search/?query="text-to-sql"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# Loading next page...
# Page 2 loaded, extracting data...
# Loading next page...
# Page 3 loaded, extracting data...
# Loading next page...
# Page 4 loaded, extracting data...
# Loading next page...
# Page 5 loaded, extracting data...
# Loading next page...
# Page 6 loaded, extracting data...
# Loading next page...
# Page 7 loaded, extracting data...
# Loading next page...
# Page 8 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql.csv
# Searching for papers related to: "nl2sql"
# https://arxiv.org/search/?query="nl2sql"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_nl2sql.csv
# Searching for papers related to: "t2sql"
# https://arxiv.org/search/?query="t2sql"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql"
# https://arxiv.org/search/?query="text2sql"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text2sql.csv
# Searching for papers related to: "natural language to sql"
# https://arxiv.org/search/?query="natural+language+to+sql"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# Loading next page...
# Page 2 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_natural_language_to_sql.csv
# Searching for papers related to: "semantic parsing to sql"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_semantic_parsing_to_sql.csv
# Searching for papers related to: "nl to sql"
# https://arxiv.org/search/?query="nl+to+sql"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_nl_to_sql.csv
# Searching for papers related to: "text-to-sql" AND "security"
# https://arxiv.org/search/?query="text-to-sql"+AND+"security"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_security.csv
# Searching for papers related to: "text-to-sql" AND "access control"
# https://arxiv.org/search/?query="text-to-sql"+AND+"access+control"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_access_control.csv
# Searching for papers related to: "text-to-sql" AND "injection"
# https://arxiv.org/search/?query="text-to-sql"+AND+"injection"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_injection.csv
# Searching for papers related to: "text-to-sql" AND "prompt injection"
# https://arxiv.org/search/?query="text-to-sql"+AND+"prompt+injection"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text-to-sql" AND "defense"
# https://arxiv.org/search/?query="text-to-sql"+AND+"defense"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_defense.csv
# Searching for papers related to: "text-to-sql" AND "attack"
# https://arxiv.org/search/?query="text-to-sql"+AND+"attack"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_attack.csv
# Searching for papers related to: "text-to-sql" AND "vulnerability"
# https://arxiv.org/search/?query="text-to-sql"+AND+"vulnerability"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_vulnerability.csv
# Searching for papers related to: "nl2sql" AND "security"
# https://arxiv.org/search/?query="nl2sql"+AND+"security"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "access control"
# https://arxiv.org/search/?query="nl2sql"+AND+"access+control"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_nl2sql_AND_access_control.csv
# Searching for papers related to: "nl2sql" AND "injection"
# https://arxiv.org/search/?query="nl2sql"+AND+"injection"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "prompt injection"
# https://arxiv.org/search/?query="nl2sql"+AND+"prompt+injection"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "defense"
# https://arxiv.org/search/?query="nl2sql"+AND+"defense"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "attack"
# https://arxiv.org/search/?query="nl2sql"+AND+"attack"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "vulnerability"
# https://arxiv.org/search/?query="nl2sql"+AND+"vulnerability"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "security"
# https://arxiv.org/search/?query="t2sql"+AND+"security"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "access control"
# https://arxiv.org/search/?query="t2sql"+AND+"access+control"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "injection"
# https://arxiv.org/search/?query="t2sql"+AND+"injection"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "prompt injection"
# https://arxiv.org/search/?query="t2sql"+AND+"prompt+injection"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "defense"
# https://arxiv.org/search/?query="t2sql"+AND+"defense"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "attack"
# https://arxiv.org/search/?query="t2sql"+AND+"attack"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "vulnerability"
# https://arxiv.org/search/?query="t2sql"+AND+"vulnerability"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "security"
# https://arxiv.org/search/?query="text2sql"+AND+"security"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text2sql_AND_security.csv
# Searching for papers related to: "text2sql" AND "access control"
# https://arxiv.org/search/?query="text2sql"+AND+"access+control"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "injection"
# https://arxiv.org/search/?query="text2sql"+AND+"injection"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "prompt injection"
# https://arxiv.org/search/?query="text2sql"+AND+"prompt+injection"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "defense"
# https://arxiv.org/search/?query="text2sql"+AND+"defense"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "attack"
# https://arxiv.org/search/?query="text2sql"+AND+"attack"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "vulnerability"
# https://arxiv.org/search/?query="text2sql"+AND+"vulnerability"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "security"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"security"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_natural_language_to_sql_AND_security.csv
# Searching for papers related to: "natural language to sql" AND "access control"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"access+control"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "injection"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"injection"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_natural_language_to_sql_AND_injection.csv
# Searching for papers related to: "natural language to sql" AND "prompt injection"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"prompt+injection"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "defense"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"defense"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "attack"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"attack"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "vulnerability"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"vulnerability"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "security"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"security"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "access control"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"access+control"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "injection"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"injection"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "prompt injection"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"prompt+injection"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "defense"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"defense"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "attack"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"attack"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "vulnerability"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"vulnerability"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "security"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"security"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "access control"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"access+control"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "injection"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"injection"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "prompt injection"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"prompt+injection"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "defense"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"defense"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "attack"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"attack"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "vulnerability"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"vulnerability"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text-to-sql" AND "llm"
# https://arxiv.org/search/?query="text-to-sql"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# Loading next page...
# Page 2 loaded, extracting data...
# Loading next page...
# Page 3 loaded, extracting data...
# Loading next page...
# Page 4 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_llm.csv
# Searching for papers related to: "text-to-sql" AND "large language model"
# https://arxiv.org/search/?query="text-to-sql"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# Loading next page...
# Page 2 loaded, extracting data...
# Loading next page...
# Error:
# The page is refreshed. Please wait until the page is refreshed or loaded.
# Version: 4.1.0.18
# Data saved to crawl_by_text-to-sql_AND_large_language_model.csv
# Searching for papers related to: "nl2sql" AND "llm"
# https://arxiv.org/search/?query="nl2sql"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_nl2sql_AND_llm.csv
# Searching for papers related to: "nl2sql" AND "large language model"
# https://arxiv.org/search/?query="nl2sql"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_nl2sql_AND_large_language_model.csv
# Searching for papers related to: "t2sql" AND "llm"
# https://arxiv.org/search/?query="t2sql"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "large language model"
# https://arxiv.org/search/?query="t2sql"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "llm"
# https://arxiv.org/search/?query="text2sql"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text2sql_AND_llm.csv
# Searching for papers related to: "text2sql" AND "large language model"
# https://arxiv.org/search/?query="text2sql"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text2sql_AND_large_language_model.csv
# Searching for papers related to: "natural language to sql" AND "llm"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_natural_language_to_sql_AND_llm.csv
# Searching for papers related to: "natural language to sql" AND "large language model"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_natural_language_to_sql_AND_large_language_model.csv
# Searching for papers related to: "semantic parsing to sql" AND "llm"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_semantic_parsing_to_sql_AND_llm.csv
# Searching for papers related to: "semantic parsing to sql" AND "large language model"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "llm"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_nl_to_sql_AND_llm.csv
# Searching for papers related to: "nl to sql" AND "large language model"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_nl_to_sql_AND_large_language_model.csv
# Searching for papers related to: "text-to-sql" AND "security" AND "llm"
# https://arxiv.org/search/?query="text-to-sql"+AND+"security"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_security_AND_llm.csv
# Searching for papers related to: "text-to-sql" AND "security" AND "large language model"
# https://arxiv.org/search/?query="text-to-sql"+AND+"security"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_security_AND_large_language_model.csv
# Searching for papers related to: "text-to-sql" AND "access control" AND "llm"
# https://arxiv.org/search/?query="text-to-sql"+AND+"access+control"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_access_control_AND_llm.csv
# Searching for papers related to: "text-to-sql" AND "access control" AND "large language model"
# https://arxiv.org/search/?query="text-to-sql"+AND+"access+control"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text-to-sql" AND "injection" AND "llm"
# https://arxiv.org/search/?query="text-to-sql"+AND+"injection"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_injection_AND_llm.csv
# Searching for papers related to: "text-to-sql" AND "injection" AND "large language model"
# https://arxiv.org/search/?query="text-to-sql"+AND+"injection"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_injection_AND_large_language_model.csv
# Searching for papers related to: "text-to-sql" AND "prompt injection" AND "llm"
# https://arxiv.org/search/?query="text-to-sql"+AND+"prompt+injection"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text-to-sql" AND "prompt injection" AND "large language model"
# https://arxiv.org/search/?query="text-to-sql"+AND+"prompt+injection"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text-to-sql" AND "defense" AND "llm"
# https://arxiv.org/search/?query="text-to-sql"+AND+"defense"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_defense_AND_llm.csv
# Searching for papers related to: "text-to-sql" AND "defense" AND "large language model"
# https://arxiv.org/search/?query="text-to-sql"+AND+"defense"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_defense_AND_large_language_model.csv
# Searching for papers related to: "text-to-sql" AND "attack" AND "llm"
# https://arxiv.org/search/?query="text-to-sql"+AND+"attack"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_attack_AND_llm.csv
# Searching for papers related to: "text-to-sql" AND "attack" AND "large language model"
# https://arxiv.org/search/?query="text-to-sql"+AND+"attack"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_attack_AND_large_language_model.csv
# Searching for papers related to: "text-to-sql" AND "vulnerability" AND "llm"
# https://arxiv.org/search/?query="text-to-sql"+AND+"vulnerability"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_vulnerability_AND_llm.csv
# Searching for papers related to: "text-to-sql" AND "vulnerability" AND "large language model"
# https://arxiv.org/search/?query="text-to-sql"+AND+"vulnerability"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text-to-sql_AND_vulnerability_AND_large_language_model.csv
# Searching for papers related to: "nl2sql" AND "security" AND "llm"
# https://arxiv.org/search/?query="nl2sql"+AND+"security"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "security" AND "large language model"
# https://arxiv.org/search/?query="nl2sql"+AND+"security"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "access control" AND "llm"
# https://arxiv.org/search/?query="nl2sql"+AND+"access+control"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_nl2sql_AND_access_control_AND_llm.csv
# Searching for papers related to: "nl2sql" AND "access control" AND "large language model"
# https://arxiv.org/search/?query="nl2sql"+AND+"access+control"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "injection" AND "llm"
# https://arxiv.org/search/?query="nl2sql"+AND+"injection"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "injection" AND "large language model"
# https://arxiv.org/search/?query="nl2sql"+AND+"injection"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "prompt injection" AND "llm"
# https://arxiv.org/search/?query="nl2sql"+AND+"prompt+injection"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "prompt injection" AND "large language model"
# https://arxiv.org/search/?query="nl2sql"+AND+"prompt+injection"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "defense" AND "llm"
# https://arxiv.org/search/?query="nl2sql"+AND+"defense"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "defense" AND "large language model"
# https://arxiv.org/search/?query="nl2sql"+AND+"defense"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "attack" AND "llm"
# https://arxiv.org/search/?query="nl2sql"+AND+"attack"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "attack" AND "large language model"
# https://arxiv.org/search/?query="nl2sql"+AND+"attack"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "vulnerability" AND "llm"
# https://arxiv.org/search/?query="nl2sql"+AND+"vulnerability"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl2sql" AND "vulnerability" AND "large language model"
# https://arxiv.org/search/?query="nl2sql"+AND+"vulnerability"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "security" AND "llm"
# https://arxiv.org/search/?query="t2sql"+AND+"security"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "security" AND "large language model"
# https://arxiv.org/search/?query="t2sql"+AND+"security"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "access control" AND "llm"
# https://arxiv.org/search/?query="t2sql"+AND+"access+control"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "access control" AND "large language model"
# https://arxiv.org/search/?query="t2sql"+AND+"access+control"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "injection" AND "llm"
# https://arxiv.org/search/?query="t2sql"+AND+"injection"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "injection" AND "large language model"
# https://arxiv.org/search/?query="t2sql"+AND+"injection"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "prompt injection" AND "llm"
# https://arxiv.org/search/?query="t2sql"+AND+"prompt+injection"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "prompt injection" AND "large language model"
# https://arxiv.org/search/?query="t2sql"+AND+"prompt+injection"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "defense" AND "llm"
# https://arxiv.org/search/?query="t2sql"+AND+"defense"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "defense" AND "large language model"
# https://arxiv.org/search/?query="t2sql"+AND+"defense"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "attack" AND "llm"
# https://arxiv.org/search/?query="t2sql"+AND+"attack"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "attack" AND "large language model"
# https://arxiv.org/search/?query="t2sql"+AND+"attack"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "vulnerability" AND "llm"
# https://arxiv.org/search/?query="t2sql"+AND+"vulnerability"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "t2sql" AND "vulnerability" AND "large language model"
# https://arxiv.org/search/?query="t2sql"+AND+"vulnerability"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "security" AND "llm"
# https://arxiv.org/search/?query="text2sql"+AND+"security"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text2sql_AND_security_AND_llm.csv
# Searching for papers related to: "text2sql" AND "security" AND "large language model"
# https://arxiv.org/search/?query="text2sql"+AND+"security"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_text2sql_AND_security_AND_large_language_model.csv
# Searching for papers related to: "text2sql" AND "access control" AND "llm"
# https://arxiv.org/search/?query="text2sql"+AND+"access+control"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "access control" AND "large language model"
# https://arxiv.org/search/?query="text2sql"+AND+"access+control"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "injection" AND "llm"
# https://arxiv.org/search/?query="text2sql"+AND+"injection"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "injection" AND "large language model"
# https://arxiv.org/search/?query="text2sql"+AND+"injection"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "prompt injection" AND "llm"
# https://arxiv.org/search/?query="text2sql"+AND+"prompt+injection"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "prompt injection" AND "large language model"
# https://arxiv.org/search/?query="text2sql"+AND+"prompt+injection"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "defense" AND "llm"
# https://arxiv.org/search/?query="text2sql"+AND+"defense"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "defense" AND "large language model"
# https://arxiv.org/search/?query="text2sql"+AND+"defense"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "attack" AND "llm"
# https://arxiv.org/search/?query="text2sql"+AND+"attack"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "attack" AND "large language model"
# https://arxiv.org/search/?query="text2sql"+AND+"attack"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "vulnerability" AND "llm"
# https://arxiv.org/search/?query="text2sql"+AND+"vulnerability"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql" AND "vulnerability" AND "large language model"
# https://arxiv.org/search/?query="text2sql"+AND+"vulnerability"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "security" AND "llm"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"security"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to crawl_by_natural_language_to_sql_AND_security_AND_llm.csv
# Searching for papers related to: "natural language to sql" AND "security" AND "large language model"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"security"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "access control" AND "llm"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"access+control"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "access control" AND "large language model"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"access+control"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "injection" AND "llm"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"injection"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "injection" AND "large language model"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"injection"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "prompt injection" AND "llm"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"prompt+injection"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "prompt injection" AND "large language model"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"prompt+injection"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "defense" AND "llm"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"defense"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "defense" AND "large language model"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"defense"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "attack" AND "llm"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"attack"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "attack" AND "large language model"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"attack"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "vulnerability" AND "llm"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"vulnerability"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "vulnerability" AND "large language model"
# https://arxiv.org/search/?query="natural+language+to+sql"+AND+"vulnerability"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "security" AND "llm"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"security"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "security" AND "large language model"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"security"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "access control" AND "llm"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"access+control"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "access control" AND "large language model"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"access+control"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "injection" AND "llm"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"injection"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "injection" AND "large language model"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"injection"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "prompt injection" AND "llm"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"prompt+injection"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "prompt injection" AND "large language model"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"prompt+injection"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "defense" AND "llm"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"defense"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "defense" AND "large language model"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"defense"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "attack" AND "llm"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"attack"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "attack" AND "large language model"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"attack"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "vulnerability" AND "llm"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"vulnerability"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "vulnerability" AND "large language model"
# https://arxiv.org/search/?query="semantic+parsing+to+sql"+AND+"vulnerability"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "security" AND "llm"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"security"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "security" AND "large language model"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"security"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "access control" AND "llm"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"access+control"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "access control" AND "large language model"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"access+control"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "injection" AND "llm"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"injection"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "injection" AND "large language model"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"injection"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "prompt injection" AND "llm"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"prompt+injection"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "prompt injection" AND "large language model"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"prompt+injection"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "defense" AND "llm"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"defense"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "defense" AND "large language model"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"defense"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "attack" AND "llm"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"attack"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "attack" AND "large language model"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"attack"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "vulnerability" AND "llm"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"vulnerability"+AND+"llm"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "vulnerability" AND "large language model"
# https://arxiv.org/search/?query="nl+to+sql"+AND+"vulnerability"+AND+"large+language+model"&searchtype=all&source=header&abstracts=show
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to all_arxiv_papers.csv
# Extracted 990 papers.

# %%
import pandas as pd
from DrissionPage import ChromiumPage, ChromiumOptions

# Load the CSV file
df = pd.read_csv('arxiv/all_arxiv_papers.csv')
df.head()

dois = []

option = ChromiumOptions()
# Uncomment the following lines to run in headless mode or with specific options
option.headless(on_off=True)  # Run in headless mode
# Initialize the page
page = ChromiumPage(addr_or_opts=option)

for link in df['link']:
    page.get(link)
    doi = page.ele('css:#arxiv-doi-link').attr('href')
    print(doi)
    dois.append(doi)

df['doi'] = dois
df.to_csv('arxiv/all_arxiv_papers.csv', index=False)
# Out:
# https://doi.org/10.48550/arXiv.2506.07423
# https://doi.org/10.48550/arXiv.2506.07245
# https://doi.org/10.48550/arXiv.2506.06093
# https://doi.org/10.48550/arXiv.2506.04494
# https://doi.org/10.48550/arXiv.2506.03598
# https://doi.org/10.48550/arXiv.2506.01710
# https://doi.org/10.48550/arXiv.2506.01571
# https://doi.org/10.48550/arXiv.2506.01273
# https://doi.org/10.48550/arXiv.2506.00986
# https://doi.org/10.48550/arXiv.2506.00912
# https://doi.org/10.48550/arXiv.2506.00842
# https://doi.org/10.48550/arXiv.2506.00391
# https://doi.org/10.48550/arXiv.2505.23838
# https://doi.org/10.48550/arXiv.2505.23804
# https://doi.org/10.48550/arXiv.2505.22096
# https://doi.org/10.48550/arXiv.2505.20321
# https://doi.org/10.48550/arXiv.2505.20315
# https://doi.org/10.48550/arXiv.2505.19988
# https://doi.org/10.48550/arXiv.2412.07246
# https://doi.org/10.48550/arXiv.2010.11246
# https://doi.org/10.48550/arXiv.1904.09086
# https://doi.org/10.48550/arXiv.2506.05587
# https://doi.org/10.48550/arXiv.2505.11270
# https://doi.org/10.48550/arXiv.2501.16220

# %%
import pandas as pd
papers = pd.read_csv("../raw_crawl_papers/arxiv/all_arxiv_papers.csv")
papers.head()
# Out:
#    Unnamed: 0                              link  \
# 0           0  https://arxiv.org/abs/2506.07423
# 1           1  https://arxiv.org/abs/2506.07245
# 2           2  https://arxiv.org/abs/2506.06093
# 3           3  https://arxiv.org/abs/2506.04494
# 4           4  https://arxiv.org/abs/2506.03598
#
#                            pdf_link  \
# 0  https://arxiv.org/pdf/2506.07423
# 1  https://arxiv.org/pdf/2506.07245
# 2  https://arxiv.org/pdf/2506.06093
# 3  https://arxiv.org/pdf/2506.04494
# 4  https://arxiv.org/pdf/2506.03598
#
#                                                title  \
# 0  SEED: Enhancing Text-to-SQL Performance and Pr...
# 1  SDE-SQL: Enhancing Text-to-SQL Generation in L...
# 2  Reinforcing Code Generation: Improving Text-to...
# 3  SQLens: An End-to-End Framework for Error Dete...
# 4  Auto prompt sql: a resource-efficient architec...
#
#                                              authors  \
# 0                        Janghyeon Yun, Sang-goo Lee
# 1               Wenxuan Xie, Yaxun Dai, Wenhao Jiang
# 2                    Atharv Kulkarni, Vivek Srikumar
# 3  Yue Gong, Chuan Lei, Xiao Qin, Kapil Vaidya, B...
# 4                        Zetong Tang, Qian Ma, Di Wu
#
#                                             abstract   submitted  \
# 0  Text-to-SQL enables non-experts to retrieve da...  2025-06-09
# 1  Recent advancements in large language models (...  2025-06-08
# 2  In this work, we study the problem of code gen...  2025-06-06
# 3  Text-to-SQL systems translate natural language...  2025-06-04
# 4  Using the best Text-to-SQL methods in resource...  2025-06-04
#
#                                          doi
# 0  https://doi.org/10.48550/arXiv.2506.07423
# 1  https://doi.org/10.48550/arXiv.2506.07245
# 2  https://doi.org/10.48550/arXiv.2506.06093
# 3  https://doi.org/10.48550/arXiv.2506.04494
# 4  https://doi.org/10.48550/arXiv.2506.03598

# %%
# import re
# from datetime import datetime

# def extract_date(text):
#     # Tìm mẫu "Submitted DD Month, YYYY"
#     pattern = r'Submitted (\d{1,2}) ([A-Za-z]+), (\d{4})'
#     match = re.search(pattern, text)
    
#     if match:
#         day, month, year = match.groups()
#         # Chuyển đổi thành đối tượng datetime
#         try:
#             return pd.to_datetime(f"{day} {month} {year}")
#         except:
#             return None
#     return None

# # Áp dụng hàm chuyển đổi cho cột submitted
# papers['submitted'] = papers['submitted'].apply(extract_date)

# %%
papers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  463 non-null    int64
#  1   link        463 non-null    object
#  2   pdf_link    459 non-null    object
#  3   title       463 non-null    object
#  4   authors     463 non-null    object
#  5   abstract    463 non-null    object
#  6   submitted   0 non-null      object
#  7   doi         463 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 29.1+ KB

# %%
papers.to_csv("../raw_crawl_papers/arxiv/all_arxiv_papers.csv")
