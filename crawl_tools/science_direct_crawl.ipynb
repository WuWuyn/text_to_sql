# %%
from DrissionPage import ChromiumPage, ChromiumOptions
import time
import pandas as pd
import random

# %%
def extract_paper_details(list_item: ChromiumPage) -> dict:
    """
    Extracts details from a single Science Direct paper result.
    Args:
        result (DrissionPage): The DrissionPage object representing the paper result.
    Returns:    
        dict: A dictionary containing the extracted details.
    """
    
    try:
        doi = list_item.attr('data-doi') if list_item.attr('data-doi') else None
        
        title_anchor = list_item.ele('css:a.anchor.result-list-title-link')
        if title_anchor:
            title = title_anchor.text if title_anchor.text else None
            link = title_anchor.attr('href') if title_anchor.attr('href') else None
    
        pdf_anchor = list_item.ele('css:a.anchor.download-link') if list_item.ele('css:a.anchor.download-link') else None
        if pdf_anchor:
            pdf_link = pdf_anchor.attr('href') if pdf_anchor.attr('href') else None
        else: pdf_link = None

        print(f"Extracted DOI: {doi}")
        print(f"Extracted Title: {title}")  
        print(f"Extracted Link: {link}")    
        print(f"Extracted PDF Link: {pdf_link}")    

    except Exception as e:
        print(f"Error extracting details: {e}")

    return {
        'link': link,
        'pdf_link': pdf_link if pdf_link else None,
        'title': title,
        'doi': f'https://doi.org/{doi}' if doi else None,
    }

# %%
def paper_crawl(keywords: str) -> list:
    """
    Crawls arXiv for papers based on the given keywords.
    Args:
        keywords (str): The keywords to search for.     
    Returns:
        list: A list of dictionaries containing paper details.
    """

    #List of paper data
    papers_data = []

    # Navigate to the search page
    # Construct the search URL
    search_url = f'https://www.sciencedirect.com/search?qs={keywords}'
    print(search_url)
    
    # option = ChromiumOptions()
    # # Uncomment the following lines to run in headless mode or with specific options
    # option.headless(on_off=True)  # Run in headless mode
    # # Initialize the page
    page = ChromiumPage()
    try:
        page.get(search_url)
        cnt = 1
        while True:
            # Wait for the page to load fully
            page.wait.ele_displayed('css:li.ResultItem.col-xs-24.push-m', timeout=3)            
            print(f"Page {cnt} loaded, extracting data...")

            # Target the result element
            list_item = page.eles('css:li.ResultItem.col-xs-24.push-m')

            # Loop through each result and extract details
            for result in list_item:
                paper_data = []
                try:
                    paper_data = extract_paper_details(result)
                    papers_data.append(paper_data)
                except Exception as e:
                    print(f"Error extracting data from a result: {e}")

            # Check if the "Load More" button is present
            next_button = page.ele('css:a[data-aa-name="srp-next-page"]')
            if next_button:
                next_button.click()
                cnt += 1
                print(f"Loading next page...")
            else:
                print("No more pages to load.")
                break

    except Exception as e:
        print(f"Error: {e}")
    
    finally:
        page.quit()
        return papers_data

# %%
def save_to_csv(data: list, filename: str) -> None:
    """
    Save the extracted data to a CSV file.
    """
    try:
        df = pd.DataFrame(data)
        df.drop_duplicates(subset=['link'], inplace=True)
        df.to_csv(f"science_direct/{filename}", index=False)
        print(f"Data saved to {filename}")
    except Exception as e:
        print(f"Error saving data to CSV: {e}")

# %%
import itertools

def combination_keywords(sets):
    """Tạo danh sách các chuỗi từ khóa từ một danh sách các bộ từ khóa."""
    if not sets:
        return []
    combinations = itertools.product(*sets)
    return [' AND '.join(combo) for combo in combinations]

def generate_all_combinations(t2sql, security, llm):
    """Tạo danh sách tất cả các tổ hợp từ khóa theo các trường hợp yêu cầu."""
    # Định nghĩa các trường hợp cần tạo tổ hợp
    cases = [
        [t2sql],                    # Chỉ t2sql
        [t2sql, security],          # t2sql + security
        [t2sql, llm],               # t2sql + llm
        [t2sql, security, llm]      # t2sql + security + llm
    ]
    
    # Tạo và hợp nhất tất cả các tổ hợp
    all_combinations = []
    for case in cases:
        all_combinations.extend(combination_keywords(case))
    
    return all_combinations

# %%
def crawl_science_direct():
    """
    Main function to run the pipeline.
    """

    #Thêm ngoặc chính xác bộ keywords
    t2sql = ['"text-to-sql"', '"nl2sql"', '"t2sql"', '"text2sql"', '"natural language to sql"', 
             '"semantic parsing to sql"', '"nl to sql"']
    security = ['"security"', '"access control"', '"injection"', '"prompt injection"', '"defense"', '"attack"', '"vulnerability"']
    llm = ['"llm"', '"large language model"']

    keywords = generate_all_combinations(t2sql, security, llm)

    tmp = []

    # Crawl papers
    for keyword in keywords:
        print(f"Searching for papers related to: {keyword}")
        keyword_1 = keyword.strip()
        keyword_1 = keyword_1.replace(" ", "%20")
        papers_data = paper_crawl(keyword_1)

        if len(papers_data) > 0:
            keyword = keyword.replace('"', '')
            keyword = keyword.replace(' ', '_')
            save_to_csv(papers_data, f"crawl_by_{keyword}.csv")

        tmp.extend(papers_data)

    if tmp:
        # Save data to CSV
        save_to_csv(tmp, "all_science_direct_papers.csv")
        print(f"Extracted {len(tmp)} papers.")

# %%
crawl_science_direct()
# Out:
# Searching for papers related to: "text-to-sql"
# https://www.sciencedirect.com/search?qs="text-to-sql"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/j.patrec.2025.04.016
# Extracted Title: SPS-SQL: Enhancing Text-to-SQL generation on small-scale LLMs with pre-synthesized queries
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0167865525001497
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.patcog.2025.111800
# Extracted Title: Graph-empowered Text-to-SQL generation on Electronic Medical Records
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0031320325004601
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.nlp.2025.100135
# Extracted Title: Fine-tuning text-to-SQL models with reinforcement-learning training objectives
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2949719125000111
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2949719125000111/pdfft?md5=435c497abba7c389db6999717a31c263&pid=1-s2.0-S2949719125000111-main.pdf
# Extracted DOI: 10.1016/j.neucom.2024.129293
# Extracted Title: Decoupling SQL query hardness parsing for text-to-SQL
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0925231224020642
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.knosys.2024.112697
# Extracted Title: Bridging the gap between text-to-SQL research and real-world applications: A unified all-in-one framework for text-to-SQL
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0950705124013315
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.ipm.2025.104136
# Extracted Title: Optimizing text-to-SQL conversion techniques through the integration of intelligent agents and large language models
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306457325000780
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S0306457325000780/pdfft?md5=8fcfd69c5d1a9e40dac2abdb248e6ac4&pid=1-s2.0-S0306457325000780-main.pdf
# Extracted DOI: 10.1016/j.ipm.2024.103978
# Extracted Title: Multi-pattern retrieval-augmented framework for Text-to-SQL with Poincaré-Skeleton retrieval and meta-instruction reasoning
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306457324003376
# Extracted PDF Link: None
# Extracted DOI: 10.2196/32698
# Extracted Title: A BERT-Based Generation Model to Transform Medical Texts to SQL Queries for Electronic Medical Records: Model Development and Validation
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2291969421000843
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.dib.2022.108211
# Extracted Title: SEOSS-Queries - a software engineering dataset for text-to-SQL and question answering tasks
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2352340922004152
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2352340922004152/pdfft?md5=4d80643c0c4ebab3933afe7b395cc654&pid=1-s2.0-S2352340922004152-main.pdf
# Extracted DOI: 10.1016/j.neucom.2021.08.134
# Extracted Title: ER-SQL: Learning enhanced representation for Text-to-SQL using table contents
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S092523122101345X
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S092523122101345X/pdfft?md5=4e93be7f845bc2ebff45c3f149a7ebc4&pid=1-s2.0-S092523122101345X-main.pdf
# Extracted DOI: 10.1016/j.neunet.2021.07.014
# Extracted Title: An interaction-modeling mechanism for context-dependent Text-to-SQL translation based on heterogeneous graph aggregation
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S089360802100277X
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.eswa.2025.128293
# Extracted Title: EzSQL: An SQL intermediate representation for improving SQL-to-text generation
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0957417425019128
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.array.2024.100368
# Extracted Title: Combining computational linguistics with sentence embedding to create a zero-shot NLIDB
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2590005624000341
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2590005624000341/pdfft?md5=90b42017997a5255ec0f6c73555a468f&pid=1-s2.0-S2590005624000341-main.pdf
# Extracted DOI: 10.1016/j.knosys.2023.110416
# Extracted Title: Creating CREATE queries with multi-task deep neural networks
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0950705123001661
# Extracted PDF Link: None
# Extracted DOI: 10.1016/S1876-3804(25)60546-5
# Extracted Title: Construction and preliminary application of large language model for reservoir performance analysis
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1876380425605465
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1876380425605465/pdfft?md5=2980d560b069dc8f08898cf10ce59e4d&pid=1-s2.0-S1876380425605465-main.pdf
# Extracted DOI: 10.1016/j.knosys.2025.113047
# Extracted Title: Enhancing knowledge retrieval with in-context learning and semantic search through generative AI
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0950705125000942
# Extracted PDF Link: None
# Extracted DOI: 10.2196/53636
# Extracted Title: Question Answering for Electronic Health Records: Scoping Review of Datasets and Models
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1438887124007222
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.knosys.2023.110264
# Extracted Title: Schema dependency-enhanced curriculum pre-training for table semantic parsing
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S095070512300014X
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.procs.2024.09.178
# Extracted Title: A Survey on RAG with LLMs
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1877050924021860
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1877050924021860/pdfft?md5=56df04a8e33ba85831806d089b1c109f&pid=1-s2.0-S1877050924021860-main.pdf
# Extracted DOI: 10.1016/j.mlwa.2025.100641
# Extracted Title: ASKSQL: Enabling cost-effective natural language to SQL conversion for enhanced analytics and search
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2666827025000246
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2666827025000246/pdfft?md5=ddb82ec9b50bccde5254558b7bbd736b&pid=1-s2.0-S2666827025000246-main.pdf
# Extracted DOI: 10.1016/j.jnca.2025.104231
# Extracted Title: Real-time tracking railway intruders using multiple-agent cooperated large language models with edge stream processing engine
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1084804525001286
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.jbi.2024.104649
# Extracted Title: Criteria2Query 3.0: Leveraging generative large language models for clinical trial eligibility query generation
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1532046424000674
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1532046424000674/pdfft?md5=284acfa31a6d24fe0fa8a47b190f0594&pid=1-s2.0-S1532046424000674-main.pdf
# Extracted DOI: 10.1016/j.asoc.2024.111818
# Extracted Title: The fusion of fuzzy theories and natural language processing: A state-of-the-art survey
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1568494624005921
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.eswa.2023.120383
# Extracted Title: SPARQL-QA-v2 system for Knowledge Base Question Answering
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0957417423008850
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.websem.2024.100858
# Extracted Title: Knowledge Graphs as a source of trust for LLM-powered enterprise question answering
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1570826824000441
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1570826824000441/pdfft?md5=05f2c90d1a9b90c0531433fb64115234&pid=1-s2.0-S1570826824000441-main.pdf
# Loading next page...
# Page 2 loaded, extracting data...
# Extracted DOI: 10.2196/63216
# Extracted Title: Large Language Model–Based Critical Care Big Data Deployment and Extraction: Descriptive Analysis
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2291969425000547
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.eswa.2025.128263
# Extracted Title: SPARKLE: Enhancing SPARQL generation with direct KG integration in decoding
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0957417425018822
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.eswa.2024.125090
# Extracted Title: GS-CBR-KBQA: Graph-structured case-based reasoning for knowledge base question answering
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0957417424019572
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.mlwa.2025.100677
# Extracted Title: Generating impossible queries
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S266682702500060X
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S266682702500060X/pdfft?md5=d9bda84c1a40bc7167f27cdfbf54edf3&pid=1-s2.0-S266682702500060X-main.pdf
# Extracted DOI: 10.1016/j.jmb.2025.169013
# Extracted Title: Protein Data Bank Japan: Computational Resources for Analysis of Protein Structures
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0022283625000798
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S0022283625000798/pdfft?md5=c44ad01382d322c8fd4b09906a40f6de&pid=1-s2.0-S0022283625000798-main.pdf
# Extracted DOI: 10.1016/j.simpa.2022.100357
# Extracted Title: AI-Tornado: An AI-based Software for analyzing Tornadoes from disaster event dataset
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2665963822000719
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2665963822000719/pdfft?md5=e49d1c38c7c6eb98e7fa6f829e3f7589&pid=1-s2.0-S2665963822000719-main.pdf
# Extracted DOI: 10.1016/B978-155558335-4/50019-1
# Extracted Title: chapter D: Syntax conventions
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781555583354500191
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.autcon.2023.104902
# Extracted Title: Two-stage Text-to-BIMQL semantic parsing for building information model extraction using graph neural networks
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0926580523001620
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-1-59-749747-3.00008-9
# Extracted Title: Chapter 8: Analyzing your Security Information with FortiAnalyzer
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781597497473000089
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-0-12-804399-8.00010-7
# Extracted Title: Chapter 10: Introduction to SQL
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9780128043998000107
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.ipm.2017.08.004
# Extracted Title: Approaches for preserving content integrity of sensitive online Arabic content: A survey and research challenges
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306457316305118
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.promfg.2017.07.319
# Extracted Title: Improving the Efficiency of Large Manufacturing Assembly Plants
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2351978917305279
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2351978917305279/pdfft?md5=c698315ec3ee9250e526e98b2068861c&pid=1-s2.0-S2351978917305279-main.pdf
# Extracted DOI: 10.1016/B978-155860456-8/50030-8
# Extracted Title: Appendix F: The SQL Standardization Process
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781558604568500308
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-0-12-375697-8.50003-0
# Extracted Title: 3: Introduction to SQL
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9780123756978500030
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.ipm.2025.104159
# Extracted Title: Enhancing scientific table understanding with type-guided chain-of-thought
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306457325001001
# Extracted PDF Link: None
# Extracted DOI: 10.1007/s12205-023-0825-2
# Extracted Title: Cost Estimation Model Based on Building Information Modeling and Virtual Reality for Customizing Presold Homes
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1226798824040868
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1226798824040868/pdfft?md5=ae3c34673b0cbedb03a41e0a6510bd9a&pid=1-s2.0-S1226798824040868-main.pdf
# Extracted DOI: 10.1016/B978-012088469-8.50150-9
# Extracted Title: BilVideo Video Database Management System
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9780120884698501509
# Extracted PDF Link: None
# Extracted DOI: 10.2196/33192
# Extracted Title: A Patient-Screening Tool for Clinical Research Based on Electronic Health Records Using OpenEHR: Development Study
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2291969421000272
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.procs.2018.08.218
# Extracted Title: Prevention Structured Query Language Injection Using Regular Expression and Escape String
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1877050918315114
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1877050918315114/pdfft?md5=35fd848322e0daeea29a3ab12ff84735&pid=1-s2.0-S1877050918315114-main.pdf
# Extracted DOI: 10.1016/j.procir.2021.01.044
# Extracted Title: Neural Machine Translation for Semantic-Driven Q&A Systems in the Factory Planning
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2212827121000676
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2212827121000676/pdfft?md5=bd66cc78f17e7dcab3e32f1c416ab315&pid=1-s2.0-S2212827121000676-main.pdf
# Extracted DOI: 10.1016/j.csl.2020.101185
# Extracted Title: Learning to generate structured queries from natural language with indirect supervision
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0885230820301182
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.procs.2024.09.557
# Extracted Title: Prompting is not all you need Evaluating GPT-4 performance on a real-world ontology alignment use case
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1877050924026036
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1877050924026036/pdfft?md5=5d17778b163adbd0e3a0f88ad22469bb&pid=1-s2.0-S1877050924026036-main.pdf
# Extracted DOI: 10.1016/j.nlp.2023.100048
# Extracted Title: A survey of GPT-3 family large language models including ChatGPT and GPT-4
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2949719123000456
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2949719123000456/pdfft?md5=72753bb0aac6b7c01d0dc8bddfb62121&pid=1-s2.0-S2949719123000456-main.pdf
# Extracted DOI: 10.1016/B978-0-12-802964-0.00004-0
# Extracted Title: Chapter 4: Document Grinding and Database Digging
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9780128029640000040
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.jbi.2019.103293
# Extracted Title: Making work visible for electronic phenotype implementation: Lessons learned from the eMERGE network
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1532046419302126
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1532046419302126/pdfft?md5=afb9b5819a23571db66a5cc526eb252d&pid=1-s2.0-S1532046419302126-main.pdf
# Loading next page...
# Page 3 loaded, extracting data...
# Extracted DOI: 10.1016/j.infsof.2025.107674
# Extracted Title: XL-HQL: A HQL query generation method via XLNet and column attention
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0950584925000138
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.techsoc.2024.102808
# Extracted Title: Transforming health and wellness: Exploring the captivating convergence of rehabilitation, exercise, and cutting-edge health gadgets in the rapidly evolving tech-driven world
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0160791X24003567
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.infsof.2024.107450
# Extracted Title: Studying logging practice in machine learning-based applications
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0950584924000557
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S0950584924000557/pdfft?md5=0531d310d1fcc5f78306c5ae1e1411f6&pid=1-s2.0-S0950584924000557-main.pdf
# Extracted DOI: 10.1016/j.knosys.2024.111383
# Extracted Title: Multi-domain gate and interactive dual attention for multi-domain dialogue state tracking
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0950705124000182
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.health.2022.100016
# Extracted Title: An artificial intelligence model for heart disease detection using machine learning algorithms
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2772442522000016
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2772442522000016/pdfft?md5=8dd9494ff638a7bf0ef7fdd40122d11e&pid=1-s2.0-S2772442522000016-main.pdf
# Extracted DOI: 10.1016/j.neucom.2021.03.005
# Extracted Title: Match matrix aggregation enhanced transition-based neural network for SQL parsing
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0925231221003556
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.compedu.2015.02.009
# Extracted Title: Learning style analysis in adaptive GBL application to teach SQL
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0360131515000536
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.cose.2024.104151
# Extracted Title: SecureQwen: Leveraging LLMs for vulnerability detection in python codebases
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0167404824004565
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-155558329-3/50024-8
# Extracted Title: 16: Database as web services consumer
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781555583293500248
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.knosys.2023.110988
# Extracted Title: Sweet Apple, company? or food? Adjective-centric commonsense knowledge acquisition with taxonomy-guided induction
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0950705123007384
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-155558323-1/50003-6
# Extracted Title: 1: Introduction to Oracle SQL
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781555583231500036
# Extracted PDF Link: None
# Extracted DOI: 10.1016/0895-6111(91)90006-H
# Extracted Title: PACS database architecture and design
# Extracted Link: https://www.sciencedirect.com/science/article/pii/089561119190006H
# Extracted PDF Link: None
# Extracted DOI: 10.1016/bs.adcom.2017.08.003
# Extracted Title: Chapter Nine: NoSQL Polyglot Persistence
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0065245817300347
# Extracted PDF Link: None
# Extracted DOI: 10.1016/S1876-3804(24)60524-0
# Extracted Title: Research status and application of artificial intelligence large models in the oil and gas industry
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1876380424605240
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1876380424605240/pdfft?md5=67673ee303c5d6a22217fe5c695df5bb&pid=1-s2.0-S1876380424605240-main.pdf
# Extracted DOI: 10.1016/j.yjbinx.2020.100074
# Extracted Title: Interoperability of population-based patient registries
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2590177X20300081
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2590177X20300081/pdfft?md5=33d69245eb832f52a0b2356c5c40c19f&pid=1-s2.0-S2590177X20300081-main.pdf
# Extracted DOI: 10.1016/B978-155860677-7/50004-3
# Extracted Title: Chapter 3: Typed Tables
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781558606777500043
# Extracted PDF Link: None
# Extracted DOI: 10.1016/S0020-0255(02)00172-X
# Extracted Title: A rule-based video database system architecture
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S002002550200172X
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-012168030-5/50012-7
# Extracted Title: 11: Visual Queries
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9780121680305500127
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-0-12-381414-2.00009-9
# Extracted Title: Chapter 9: Common fact model for assurance content
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9780123814142000099
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.is.2021.101752
# Extracted Title: COOL: A framework for conversational OLAP
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306437921000211
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-1-59749-424-3.00008-6
# Extracted Title: Chapter 8: Code-Level Defenses
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781597494243000086
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-159749176-1.50007-2
# Extracted Title: Chapter 4: Document Grinding and Database Digging
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781597491761500072
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.is.2014.11.006
# Extracted Title: INDREX: In-database relation extraction
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306437914001823
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.jss.2008.04.027
# Extracted Title: OCL2Trigger: Deriving active mechanisms for relational databases using Model-Driven Architecture
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0164121208000836
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.apenergy.2024.125059
# Extracted Title: Deep generative models in energy system applications: Review, challenges, and future directions
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306261924024437
# Extracted PDF Link: None
# Loading next page...
# Page 4 loaded, extracting data...
# Extracted DOI: 10.1016/B978-193183636-4/50015-4
# Extracted Title: Chapter 10: Document Grinding and Database Digging
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781931836364500154
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-1-59-749963-7.00008-6
# Extracted Title: Chapter 8: Code-level defenses
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781597499637000086
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-1-59749-424-3.00003-7
# Extracted Title: Chapter 3: Reviewing Code for SQL Injection
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781597494243000037
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.is.2006.09.003
# Extracted Title: Product lines for digital information products
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306437906000809
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-155860456-8/50020-5
# Extracted Title: Chapter 19: Call-Level Interface (CLI)
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781558604568500205
# Extracted PDF Link: None
# Extracted DOI: 10.1016/S0306-4379(99)00002-2
# Extracted Title: Grammars++ for modelling information in text
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306437999000022
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-193183604-3/50012-6
# Extracted Title: Chapter 7: Implementing Snort Output Plug-Ins
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781931836043500126
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-1-59-749963-7.00003-7
# Extracted Title: Chapter 3: Reviewing Code for SQL Injection
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781597499637000037
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.knosys.2018.11.010
# Extracted Title: SemIndex+: A semantic indexing scheme for structured, unstructured, and partly structured data
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0950705118305549
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.datak.2018.07.007
# Extracted Title: Full-fledged semantic indexing and querying model designed for seamless integration in legacy RDBMS
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0169023X16301835
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.iotcps.2025.01.001
# Extracted Title: Generative AI in cybersecurity: A comprehensive review of LLM applications and vulnerabilities
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2667345225000082
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2667345225000082/pdfft?md5=da8ff6376b63e59da75af5d1ff5d2818&pid=1-s2.0-S2667345225000082-main.pdf
# Extracted DOI: 10.1016/B978-155558329-3/50007-8
# Extracted Title: 3: Developing and running java in the database
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781555583293500078
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-0-12-804278-6.00003-3
# Extracted Title: 3: Security Threats Are Real (STAR)
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9780128042786000033
# Extracted PDF Link: None
# No more pages to load.
# Data saved to crawl_by_text-to-sql.csv
# Searching for papers related to: "nl2sql"
# https://www.sciencedirect.com/search?qs="nl2sql"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/j.mlwa.2025.100641
# Extracted Title: ASKSQL: Enabling cost-effective natural language to SQL conversion for enhanced analytics and search
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2666827025000246
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2666827025000246/pdfft?md5=ddb82ec9b50bccde5254558b7bbd736b&pid=1-s2.0-S2666827025000246-main.pdf
# Extracted DOI: 10.1016/B978-0-443-28824-1.50464-6
# Extracted Title: Enhancing real-time data querying in chemical engineering: A bilevel vocabulary-constrained seq2seq approach
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9780443288241504646
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.knosys.2024.112718
# Extracted Title: A confidence-based knowledge integration framework for cross-domain table question answering
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0950705124013522
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S0950705124013522/pdfft?md5=c9f61e565617fdfe986be590e8456d7b&pid=1-s2.0-S0950705124013522-main.pdf
# Extracted DOI: 10.1016/j.bdr.2021.100304
# Extracted Title: Survey on Learnable Databases: A Machine Learning Perspective
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2214579621001210
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.knosys.2023.110416
# Extracted Title: Creating CREATE queries with multi-task deep neural networks
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0950705123001661
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.procs.2025.05.061
# Extracted Title: Design of Intelligent Q&A System Based on Knowledge Graph Combined with Large Language Model
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1877050925019088
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1877050925019088/pdfft?md5=ddbf12a43a1cc67abcaccca62efc44fc&pid=1-s2.0-S1877050925019088-main.pdf
# Extracted DOI: 10.1016/B978-0-323-90118-5.00008-4
# Extracted Title: Chapter 8: Applications and future of machine reading comprehension
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9780323901185000084
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.visinf.2024.04.003
# Extracted Title: Generative AI for visualization: State of the art and future directions
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2468502X24000160
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2468502X24000160/pdfft?md5=c309ceeb991e85de9bb7a69d53c32032&pid=1-s2.0-S2468502X24000160-main.pdf
# Extracted DOI: 10.1016/B978-0-323-90118-5.00016-3
# Extracted Title: Index
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9780323901185000163
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/B9780323901185000163/pdfft?md5=c816d26c8e8219098c485e1d2c990727&pid=3-s2.0-B9780323901185000163-main.pdf
# Extracted DOI: 10.1016/j.neucom.2024.127795
# Extracted Title: KFEX-N : A table-text data question-answering model based on knowledge-fusion encoder and EX-N tree decoder
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0925231224005666
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.neucom.2025.130395
# Extracted Title: QueryAccelerator: A SQL converter capturing and transforming the slow plan
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0925231225010677
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.neucom.2021.08.134
# Extracted Title: ER-SQL: Learning enhanced representation for Text-to-SQL using table contents
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S092523122101345X
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S092523122101345X/pdfft?md5=4e93be7f845bc2ebff45c3f149a7ebc4&pid=1-s2.0-S092523122101345X-main.pdf
# No more pages to load.
# Data saved to crawl_by_nl2sql.csv
# Searching for papers related to: "t2sql"
# https://www.sciencedirect.com/search?qs="t2sql"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "text2sql"
# https://www.sciencedirect.com/search?qs="text2sql"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/j.jmsy.2025.02.008
# Extracted Title: Chat with MES: LLM-driven user interface for manipulating garment manufacturing system through natural language
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S027861252500038X
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S027861252500038X/pdfft?md5=3571881ed2e5d16154cd9144d41094c6&pid=1-s2.0-S027861252500038X-main.pdf
# Extracted DOI: 10.1016/j.aiopen.2022.12.003
# Extracted Title: A survey on complex factual question answering
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2666651022000249
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2666651022000249/pdfft?md5=64a2720b1dfa7108fa927c044f7d2b97&pid=1-s2.0-S2666651022000249-main.pdf
# Extracted DOI: 10.1016/j.enbuild.2025.115515
# Extracted Title: A large language model-based building operation and maintenance information query
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0378778825002452
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.infsof.2025.107674
# Extracted Title: XL-HQL: A HQL query generation method via XLNet and column attention
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0950584925000138
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.simpa.2021.100058
# Extracted Title: Spark NLP: Natural Language Understanding at Scale
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2665963821000063
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2665963821000063/pdfft?md5=bf4a62b4635947b3c2322056b9614d33&pid=1-s2.0-S2665963821000063-main.pdf
# Extracted DOI: 10.1016/S1876-3804(24)60524-0
# Extracted Title: Research status and application of artificial intelligence large models in the oil and gas industry
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1876380424605240
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1876380424605240/pdfft?md5=67673ee303c5d6a22217fe5c695df5bb&pid=1-s2.0-S1876380424605240-main.pdf
# Extracted DOI: 10.1016/j.neucom.2024.128154
# Extracted Title: A survey for table recognition based on deep learning
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0925231224009251
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.artint.2024.104257
# Extracted Title: Integrating symbolic reasoning into neural generative models for design generation
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0004370224001930
# Extracted PDF Link: None
# No more pages to load.
# Data saved to crawl_by_text2sql.csv
# Searching for papers related to: "natural language to sql"
# https://www.sciencedirect.com/search?qs="natural%20language%20to%20sql"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/j.mlwa.2025.100641
# Extracted Title: ASKSQL: Enabling cost-effective natural language to SQL conversion for enhanced analytics and search
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2666827025000246
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2666827025000246/pdfft?md5=ddb82ec9b50bccde5254558b7bbd736b&pid=1-s2.0-S2666827025000246-main.pdf
# Extracted DOI: 10.1016/B978-0-443-28824-1.50464-6
# Extracted Title: Enhancing real-time data querying in chemical engineering: A bilevel vocabulary-constrained seq2seq approach
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9780443288241504646
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.ipm.2025.104136
# Extracted Title: Optimizing text-to-SQL conversion techniques through the integration of intelligent agents and large language models
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306457325000780
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S0306457325000780/pdfft?md5=8fcfd69c5d1a9e40dac2abdb248e6ac4&pid=1-s2.0-S0306457325000780-main.pdf
# Extracted DOI: 10.1016/j.knosys.2024.112697
# Extracted Title: Bridging the gap between text-to-SQL research and real-world applications: A unified all-in-one framework for text-to-SQL
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0950705124013315
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.array.2024.100368
# Extracted Title: Combining computational linguistics with sentence embedding to create a zero-shot NLIDB
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2590005624000341
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2590005624000341/pdfft?md5=90b42017997a5255ec0f6c73555a468f&pid=1-s2.0-S2590005624000341-main.pdf
# Extracted DOI: 10.1016/j.csl.2020.101185
# Extracted Title: Learning to generate structured queries from natural language with indirect supervision
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0885230820301182
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.patrec.2025.04.016
# Extracted Title: SPS-SQL: Enhancing Text-to-SQL generation on small-scale LLMs with pre-synthesized queries
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0167865525001497
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.esmorw.2024.100109
# Extracted Title: Data analytics for real-world data integration in TKI-treated NSCLC patients using electronic health records
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2949820124000870
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2949820124000870/pdfft?md5=589f189ea664be2516ea43315c966f42&pid=1-s2.0-S2949820124000870-main.pdf
# Extracted DOI: 10.1016/j.mlwa.2025.100677
# Extracted Title: Generating impossible queries
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S266682702500060X
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S266682702500060X/pdfft?md5=d9bda84c1a40bc7167f27cdfbf54edf3&pid=1-s2.0-S266682702500060X-main.pdf
# Extracted DOI: 10.1016/j.ipm.2024.103978
# Extracted Title: Multi-pattern retrieval-augmented framework for Text-to-SQL with Poincaré-Skeleton retrieval and meta-instruction reasoning
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306457324003376
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.procs.2023.01.155
# Extracted Title: A Natural Language Processing System using CWS Pipeline for Extraction of Linguistic Features
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1877050923001552
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1877050923001552/pdfft?md5=a841477c50919a3d63b72406702f08c6&pid=1-s2.0-S1877050923001552-main.pdf
# Extracted DOI: 10.1016/j.datak.2004.12.002
# Extracted Title: Using semantic templates for a natural language interface to the CINDI virtual library
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0169023X04002198
# Extracted PDF Link: None
# Extracted DOI: 10.2196/18855
# Extracted Title: Text Processing for Detection of Fungal Ocular Involvement in Critical Care Patients: Cross-Sectional Study
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1438887120007049
# Extracted PDF Link: None
# Extracted DOI: 10.2196/32698
# Extracted Title: A BERT-Based Generation Model to Transform Medical Texts to SQL Queries for Electronic Medical Records: Model Development and Validation
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2291969421000843
# Extracted PDF Link: None
# Extracted DOI: 10.1016/S1876-3804(25)60546-5
# Extracted Title: Construction and preliminary application of large language model for reservoir performance analysis
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1876380425605465
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1876380425605465/pdfft?md5=2980d560b069dc8f08898cf10ce59e4d&pid=1-s2.0-S1876380425605465-main.pdf
# Extracted DOI: 10.2196/37842
# Extracted Title: Identifying Patients Who Meet Criteria for Genetic Testing of Hereditary Cancers Based on Structured and Unstructured Family Health History Data in the Electronic Health Record: Natural Language Processing Approach
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2291969422002009
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.neunet.2021.07.014
# Extracted Title: An interaction-modeling mechanism for context-dependent Text-to-SQL translation based on heterogeneous graph aggregation
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S089360802100277X
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.enbuild.2025.115515
# Extracted Title: A large language model-based building operation and maintenance information query
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0378778825002452
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.neucom.2024.129293
# Extracted Title: Decoupling SQL query hardness parsing for text-to-SQL
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0925231224020642
# Extracted PDF Link: None
# Extracted DOI: 10.1016/0003-6870(89)90073-2
# Extracted Title: Improving natural language and speech interfaces by the use of metalinguistic phenomena
# Extracted Link: https://www.sciencedirect.com/science/article/pii/0003687089900732
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.is.2004.09.002
# Extracted Title: Conversational querying
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306437904000936
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.eswa.2023.120383
# Extracted Title: SPARQL-QA-v2 system for Knowledge Base Question Answering
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0957417423008850
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.neucom.2021.08.134
# Extracted Title: ER-SQL: Learning enhanced representation for Text-to-SQL using table contents
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S092523122101345X
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S092523122101345X/pdfft?md5=4e93be7f845bc2ebff45c3f149a7ebc4&pid=1-s2.0-S092523122101345X-main.pdf
# Extracted DOI: 10.1016/j.artmed.2025.103066
# Extracted Title: Implementation of artificial intelligence approaches in oncology clinical trials: A systematic review
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0933365725000016
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.bdr.2021.100304
# Extracted Title: Survey on Learnable Databases: A Machine Learning Perspective
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2214579621001210
# Extracted PDF Link: None
# Loading next page...
# Page 2 loaded, extracting data...
# Extracted DOI: 10.1016/j.is.2023.102227
# Extracted Title: Natural language querying of process execution data
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306437923000637
# Extracted PDF Link: None
# Extracted DOI: 10.1016/S1876-3804(24)60524-0
# Extracted Title: Research status and application of artificial intelligence large models in the oil and gas industry
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1876380424605240
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1876380424605240/pdfft?md5=67673ee303c5d6a22217fe5c695df5bb&pid=1-s2.0-S1876380424605240-main.pdf
# Extracted DOI: 10.1016/B978-0-934613-53-8.50029-7
# Extracted Title: A Framework for Choosing a Database Query Language
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9780934613538500297
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.websem.2020.100586
# Extracted Title: IQA: Interactive query construction in semantic question answering systems
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1570826820300305
# Extracted PDF Link: None
# Extracted DOI: 10.1016/0020-7373(92)90041-I
# Extracted Title: A review and analysis of the usability of data management environments
# Extracted Link: https://www.sciencedirect.com/science/article/pii/002073739290041I
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-192899419-0/50011-7
# Extracted Title: Chapter 8: Microsoft English Query and Full-Text Search
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781928994190500117
# Extracted PDF Link: None
# No more pages to load.
# Data saved to crawl_by_natural_language_to_sql.csv
# Searching for papers related to: "semantic parsing to sql"
# https://www.sciencedirect.com/search?qs="semantic%20parsing%20to%20sql"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/j.neucom.2024.129293
# Extracted Title: Decoupling SQL query hardness parsing for text-to-SQL
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0925231224020642
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.nlp.2023.100013
# Extracted Title: A comprehensive review of State-of-The-Art methods for Java code generation from Natural Language Text
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2949719123000109
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2949719123000109/pdfft?md5=be9e5b50affa7e1858199a75a9faf395&pid=1-s2.0-S2949719123000109-main.pdf
# No more pages to load.
# Data saved to crawl_by_semantic_parsing_to_sql.csv
# Searching for papers related to: "nl to sql"
# https://www.sciencedirect.com/search?qs="nl%20to%20sql"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/j.knosys.2023.110264
# Extracted Title: Schema dependency-enhanced curriculum pre-training for table semantic parsing
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S095070512300014X
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-0-443-28824-1.50464-6
# Extracted Title: Enhancing real-time data querying in chemical engineering: A bilevel vocabulary-constrained seq2seq approach
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9780443288241504646
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.eswa.2023.121869
# Extracted Title: Automatic Logical Forms improve fidelity in Table-to-Text generation
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0957417423023710
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.knosys.2024.112718
# Extracted Title: A confidence-based knowledge integration framework for cross-domain table question answering
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0950705124013522
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S0950705124013522/pdfft?md5=c9f61e565617fdfe986be590e8456d7b&pid=1-s2.0-S0950705124013522-main.pdf
# Extracted DOI: 10.1016/j.eswa.2021.114712
# Extracted Title: PAROT: Translating natural language to SPARQL
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0957417421001536
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.eswax.2020.100024
# Extracted Title: PAROT: Translating natural language to SPARQL
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2590188520300032
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2590188520300032/pdfft?md5=afce18a9516c7a95c7a73ab0308ce4a5&pid=1-s2.0-S2590188520300032-main.pdf
# Extracted DOI: 10.1016/j.is.2023.102227
# Extracted Title: Natural language querying of process execution data
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306437923000637
# Extracted PDF Link: None
# Extracted DOI: 10.1016/0952-1976(93)90015-P
# Extracted Title: Intelligent user interface to SQL-based database system
# Extracted Link: https://www.sciencedirect.com/science/article/pii/095219769390015P
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.infsof.2006.06.009
# Extracted Title: Mutating database queries
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0950584906000814
# Extracted PDF Link: None
# No more pages to load.
# Data saved to crawl_by_nl_to_sql.csv
# Searching for papers related to: "text-to-sql" AND "security"
# https://www.sciencedirect.com/search?qs="text-to-sql"%20AND%20"security"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/j.nlp.2025.100135
# Extracted Title: Fine-tuning text-to-SQL models with reinforcement-learning training objectives
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2949719125000111
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2949719125000111/pdfft?md5=435c497abba7c389db6999717a31c263&pid=1-s2.0-S2949719125000111-main.pdf
# Extracted DOI: 10.1016/j.ipm.2025.104136
# Extracted Title: Optimizing text-to-SQL conversion techniques through the integration of intelligent agents and large language models
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306457325000780
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S0306457325000780/pdfft?md5=8fcfd69c5d1a9e40dac2abdb248e6ac4&pid=1-s2.0-S0306457325000780-main.pdf
# Extracted DOI: 10.1016/j.ipm.2024.103978
# Extracted Title: Multi-pattern retrieval-augmented framework for Text-to-SQL with Poincaré-Skeleton retrieval and meta-instruction reasoning
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306457324003376
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-1-59-749747-3.00008-9
# Extracted Title: Chapter 8: Analyzing your Security Information with FortiAnalyzer
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9781597497473000089
# Extracted PDF Link: None
# Extracted DOI: 10.1016/B978-0-12-804278-6.00003-3
# Extracted Title: 3: Security Threats Are Real (STAR)
# Extracted Link: https://www.sciencedirect.com/science/article/pii/B9780128042786000033
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.jnca.2025.104231
# Extracted Title: Real-time tracking railway intruders using multiple-agent cooperated large language models with edge stream processing engine
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1084804525001286
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.cose.2024.104151
# Extracted Title: SecureQwen: Leveraging LLMs for vulnerability detection in python codebases
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0167404824004565
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.iotcps.2025.01.001
# Extracted Title: Generative AI in cybersecurity: A comprehensive review of LLM applications and vulnerabilities
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2667345225000082
# ...
# Searching for papers related to: "natural language to sql" AND "access control" AND "large language model"
# https://www.sciencedirect.com/search?qs="natural%20language%20to%20sql"%20AND%20"access%20control"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/S1876-3804(24)60524-0
# Extracted Title: Research status and application of artificial intelligence large models in the oil and gas industry
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1876380424605240
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1876380424605240/pdfft?md5=67673ee303c5d6a22217fe5c695df5bb&pid=1-s2.0-S1876380424605240-main.pdf
# Extracted DOI: 10.1016/j.artmed.2025.103066
# Extracted Title: Implementation of artificial intelligence approaches in oncology clinical trials: A systematic review
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0933365725000016
# Extracted PDF Link: None
# No more pages to load.
# Data saved to crawl_by_natural_language_to_sql_AND_access_control_AND_large_language_model.csv
# Searching for papers related to: "natural language to sql" AND "injection" AND "llm"
# https://www.sciencedirect.com/search?qs="natural%20language%20to%20sql"%20AND%20"injection"%20AND%20"llm"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/S1876-3804(25)60546-5
# Extracted Title: Construction and preliminary application of large language model for reservoir performance analysis
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1876380425605465
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1876380425605465/pdfft?md5=2980d560b069dc8f08898cf10ce59e4d&pid=1-s2.0-S1876380425605465-main.pdf
# No more pages to load.
# Data saved to crawl_by_natural_language_to_sql_AND_injection_AND_llm.csv
# Searching for papers related to: "natural language to sql" AND "injection" AND "large language model"
# https://www.sciencedirect.com/search?qs="natural%20language%20to%20sql"%20AND%20"injection"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/S1876-3804(25)60546-5
# Extracted Title: Construction and preliminary application of large language model for reservoir performance analysis
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1876380425605465
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1876380425605465/pdfft?md5=2980d560b069dc8f08898cf10ce59e4d&pid=1-s2.0-S1876380425605465-main.pdf
# No more pages to load.
# Data saved to crawl_by_natural_language_to_sql_AND_injection_AND_large_language_model.csv
# Searching for papers related to: "natural language to sql" AND "prompt injection" AND "llm"
# https://www.sciencedirect.com/search?qs="natural%20language%20to%20sql"%20AND%20"prompt%20injection"%20AND%20"llm"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "prompt injection" AND "large language model"
# https://www.sciencedirect.com/search?qs="natural%20language%20to%20sql"%20AND%20"prompt%20injection"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "natural language to sql" AND "defense" AND "llm"
# https://www.sciencedirect.com/search?qs="natural%20language%20to%20sql"%20AND%20"defense"%20AND%20"llm"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/j.ipm.2024.103978
# Extracted Title: Multi-pattern retrieval-augmented framework for Text-to-SQL with Poincaré-Skeleton retrieval and meta-instruction reasoning
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306457324003376
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.artmed.2025.103066
# Extracted Title: Implementation of artificial intelligence approaches in oncology clinical trials: A systematic review
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0933365725000016
# Extracted PDF Link: None
# No more pages to load.
# Data saved to crawl_by_natural_language_to_sql_AND_defense_AND_llm.csv
# Searching for papers related to: "natural language to sql" AND "defense" AND "large language model"
# https://www.sciencedirect.com/search?qs="natural%20language%20to%20sql"%20AND%20"defense"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/j.ipm.2024.103978
# Extracted Title: Multi-pattern retrieval-augmented framework for Text-to-SQL with Poincaré-Skeleton retrieval and meta-instruction reasoning
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0306457324003376
# Extracted PDF Link: None
# Extracted DOI: 10.1016/j.artmed.2025.103066
# Extracted Title: Implementation of artificial intelligence approaches in oncology clinical trials: A systematic review
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0933365725000016
# Extracted PDF Link: None
# No more pages to load.
# Data saved to crawl_by_natural_language_to_sql_AND_defense_AND_large_language_model.csv
# Searching for papers related to: "natural language to sql" AND "attack" AND "llm"
# https://www.sciencedirect.com/search?qs="natural%20language%20to%20sql"%20AND%20"attack"%20AND%20"llm"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/S1876-3804(24)60524-0
# Extracted Title: Research status and application of artificial intelligence large models in the oil and gas industry
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1876380424605240
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1876380424605240/pdfft?md5=67673ee303c5d6a22217fe5c695df5bb&pid=1-s2.0-S1876380424605240-main.pdf
# No more pages to load.
# Data saved to crawl_by_natural_language_to_sql_AND_attack_AND_llm.csv
# Searching for papers related to: "natural language to sql" AND "attack" AND "large language model"
# https://www.sciencedirect.com/search?qs="natural%20language%20to%20sql"%20AND%20"attack"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/S1876-3804(24)60524-0
# Extracted Title: Research status and application of artificial intelligence large models in the oil and gas industry
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S1876380424605240
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S1876380424605240/pdfft?md5=67673ee303c5d6a22217fe5c695df5bb&pid=1-s2.0-S1876380424605240-main.pdf
# No more pages to load.
# Data saved to crawl_by_natural_language_to_sql_AND_attack_AND_large_language_model.csv
# Searching for papers related to: "natural language to sql" AND "vulnerability" AND "llm"
# https://www.sciencedirect.com/search?qs="natural%20language%20to%20sql"%20AND%20"vulnerability"%20AND%20"llm"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/j.artmed.2025.103066
# Extracted Title: Implementation of artificial intelligence approaches in oncology clinical trials: A systematic review
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0933365725000016
# Extracted PDF Link: None
# No more pages to load.
# Data saved to crawl_by_natural_language_to_sql_AND_vulnerability_AND_llm.csv
# Searching for papers related to: "natural language to sql" AND "vulnerability" AND "large language model"
# https://www.sciencedirect.com/search?qs="natural%20language%20to%20sql"%20AND%20"vulnerability"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/j.artmed.2025.103066
# Extracted Title: Implementation of artificial intelligence approaches in oncology clinical trials: A systematic review
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S0933365725000016
# Extracted PDF Link: None
# No more pages to load.
# Data saved to crawl_by_natural_language_to_sql_AND_vulnerability_AND_large_language_model.csv
# Searching for papers related to: "semantic parsing to sql" AND "security" AND "llm"
# https://www.sciencedirect.com/search?qs="semantic%20parsing%20to%20sql"%20AND%20"security"%20AND%20"llm"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "security" AND "large language model"
# https://www.sciencedirect.com/search?qs="semantic%20parsing%20to%20sql"%20AND%20"security"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "access control" AND "llm"
# https://www.sciencedirect.com/search?qs="semantic%20parsing%20to%20sql"%20AND%20"access%20control"%20AND%20"llm"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "access control" AND "large language model"
# https://www.sciencedirect.com/search?qs="semantic%20parsing%20to%20sql"%20AND%20"access%20control"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "injection" AND "llm"
# https://www.sciencedirect.com/search?qs="semantic%20parsing%20to%20sql"%20AND%20"injection"%20AND%20"llm"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "injection" AND "large language model"
# https://www.sciencedirect.com/search?qs="semantic%20parsing%20to%20sql"%20AND%20"injection"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "prompt injection" AND "llm"
# https://www.sciencedirect.com/search?qs="semantic%20parsing%20to%20sql"%20AND%20"prompt%20injection"%20AND%20"llm"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "prompt injection" AND "large language model"
# https://www.sciencedirect.com/search?qs="semantic%20parsing%20to%20sql"%20AND%20"prompt%20injection"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "defense" AND "llm"
# https://www.sciencedirect.com/search?qs="semantic%20parsing%20to%20sql"%20AND%20"defense"%20AND%20"llm"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "defense" AND "large language model"
# https://www.sciencedirect.com/search?qs="semantic%20parsing%20to%20sql"%20AND%20"defense"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "attack" AND "llm"
# https://www.sciencedirect.com/search?qs="semantic%20parsing%20to%20sql"%20AND%20"attack"%20AND%20"llm"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "attack" AND "large language model"
# https://www.sciencedirect.com/search?qs="semantic%20parsing%20to%20sql"%20AND%20"attack"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "semantic parsing to sql" AND "vulnerability" AND "llm"
# https://www.sciencedirect.com/search?qs="semantic%20parsing%20to%20sql"%20AND%20"vulnerability"%20AND%20"llm"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/j.nlp.2023.100013
# Extracted Title: A comprehensive review of State-of-The-Art methods for Java code generation from Natural Language Text
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2949719123000109
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2949719123000109/pdfft?md5=be9e5b50affa7e1858199a75a9faf395&pid=1-s2.0-S2949719123000109-main.pdf
# No more pages to load.
# Data saved to crawl_by_semantic_parsing_to_sql_AND_vulnerability_AND_llm.csv
# Searching for papers related to: "semantic parsing to sql" AND "vulnerability" AND "large language model"
# https://www.sciencedirect.com/search?qs="semantic%20parsing%20to%20sql"%20AND%20"vulnerability"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# Extracted DOI: 10.1016/j.nlp.2023.100013
# Extracted Title: A comprehensive review of State-of-The-Art methods for Java code generation from Natural Language Text
# Extracted Link: https://www.sciencedirect.com/science/article/pii/S2949719123000109
# Extracted PDF Link: https://www.sciencedirect.com/science/article/pii/S2949719123000109/pdfft?md5=be9e5b50affa7e1858199a75a9faf395&pid=1-s2.0-S2949719123000109-main.pdf
# No more pages to load.
# Data saved to crawl_by_semantic_parsing_to_sql_AND_vulnerability_AND_large_language_model.csv
# Searching for papers related to: "nl to sql" AND "security" AND "llm"
# https://www.sciencedirect.com/search?qs="nl%20to%20sql"%20AND%20"security"%20AND%20"llm"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "security" AND "large language model"
# https://www.sciencedirect.com/search?qs="nl%20to%20sql"%20AND%20"security"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "access control" AND "llm"
# https://www.sciencedirect.com/search?qs="nl%20to%20sql"%20AND%20"access%20control"%20AND%20"llm"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "access control" AND "large language model"
# https://www.sciencedirect.com/search?qs="nl%20to%20sql"%20AND%20"access%20control"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "injection" AND "llm"
# https://www.sciencedirect.com/search?qs="nl%20to%20sql"%20AND%20"injection"%20AND%20"llm"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "injection" AND "large language model"
# https://www.sciencedirect.com/search?qs="nl%20to%20sql"%20AND%20"injection"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "prompt injection" AND "llm"
# https://www.sciencedirect.com/search?qs="nl%20to%20sql"%20AND%20"prompt%20injection"%20AND%20"llm"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "prompt injection" AND "large language model"
# https://www.sciencedirect.com/search?qs="nl%20to%20sql"%20AND%20"prompt%20injection"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "defense" AND "llm"
# https://www.sciencedirect.com/search?qs="nl%20to%20sql"%20AND%20"defense"%20AND%20"llm"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "defense" AND "large language model"
# https://www.sciencedirect.com/search?qs="nl%20to%20sql"%20AND%20"defense"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "attack" AND "llm"
# https://www.sciencedirect.com/search?qs="nl%20to%20sql"%20AND%20"attack"%20AND%20"llm"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "attack" AND "large language model"
# https://www.sciencedirect.com/search?qs="nl%20to%20sql"%20AND%20"attack"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "vulnerability" AND "llm"
# https://www.sciencedirect.com/search?qs="nl%20to%20sql"%20AND%20"vulnerability"%20AND%20"llm"
# Page 1 loaded, extracting data...
# No more pages to load.
# Searching for papers related to: "nl to sql" AND "vulnerability" AND "large language model"
# https://www.sciencedirect.com/search?qs="nl%20to%20sql"%20AND%20"vulnerability"%20AND%20"large%20language%20model"
# Page 1 loaded, extracting data...
# No more pages to load.
# Data saved to all_science_direct_papers.csv
# Extracted 543 papers.

# %%
def get_paper_details(link: str, page: ChromiumPage) -> dict:
    """
    Function to get paper details from a specific Science Direct paper.
    """
    
    try:
        page.get(link)
        time.sleep(3)
        
        # Extract details
        title = page.ele('css:.title-text').text if page.ele('css:.title-text') else None

        given_name = page.ele('css:.given-name').text if page.ele('css:.given-name') else None

        sur_name = page.ele('css:.text.surname').text if page.ele('css:.text.surname') else None

        fullname = given_name + ' ' + sur_name if given_name and sur_name else None

        doi = page.ele('css:.anchor.doi.anchor-primary').attr('href') if page.ele('css:.anchor-text') else None

        abstract_element = page.ele('css:.abstract.author') if page.ele('css:.abstract.author') else None
        abstract_text = abstract_element.ele('css:.u-margin-s-bottom').text if abstract_element.ele('css:.u-margin-s-bottom') else None

        # Step 1: Click the "Show More" button
        page.ele("#show-more-btn").click() if page.ele("#show-more-btn") else page.ele("css:button#show-more-btn").click()
        # Step 2: Select the banner element by its ID
        banner = page.ele("#banner") if page.ele("#banner") else page.ele("css:div#banner")
        # Step 3: Wait for the dates paragraph to load within the banner
        time.sleep(1)
        # Step 4: Select the paragraph containing the dates
        dates_paragraph = banner.ele("css:p.u-margin-s-bottom", index=1) if banner.ele("css:p.u-margin-s-bottom", index=1) else banner.ele("css:div.u-margin-s-bottom", index=1)
        # Step 5: Extract the text with the dates
        dates = dates_paragraph.text if dates_paragraph else None

        return title, fullname, doi, abstract_text, dates
    except Exception as e:
        print(f"Error: {e}")
        return None, None, None, None, None

# %%
df = pd.read_csv("science_direct/all_science_direct_papers.csv")

# %%
title_lst = []
fullname_lst = []
doi_lst = []
abstract_lst = []
dates = []

option = ChromiumOptions()
# Uncomment the following lines to run in headless mode or with specific options
option.headless(on_off=True)  # Run in headless mode
# Initialize Chromium browser
page = ChromiumPage()

for link in df['link']:
    print(f"Processing link: {link}")
    title, fullname, doi, abstract_text, date = get_paper_details(link=link,page=page)
    title_lst.append(title)
    fullname_lst.append(fullname)
    doi_lst.append(doi)
    abstract_lst.append(abstract_text)
    dates.append(date)

page.quit()

print("All paper details extracted.")

df['title_re'] = title_lst
df['fullname_re'] = fullname_lst
df['doi_re'] = doi_lst
df['abstract_re'] = abstract_lst
df['submitted'] = dates
df.to_csv("all_science_direct_papers.csv", index=False)
# Out:
# Processing link: https://www.sciencedirect.com/science/article/pii/S0167865525001497
# Processing link: https://www.sciencedirect.com/science/article/pii/S0031320325004601
# Processing link: https://www.sciencedirect.com/science/article/pii/S2949719125000111
# Processing link: https://www.sciencedirect.com/science/article/pii/S0925231224020642
# Processing link: https://www.sciencedirect.com/science/article/pii/S0950705124013315
# Processing link: https://www.sciencedirect.com/science/article/pii/S0306457325000780
# Processing link: https://www.sciencedirect.com/science/article/pii/S0306457324003376
# Processing link: https://www.sciencedirect.com/science/article/pii/S2291969421000843
# Processing link: https://www.sciencedirect.com/science/article/pii/S2352340922004152
# Processing link: https://www.sciencedirect.com/science/article/pii/S092523122101345X
# Processing link: https://www.sciencedirect.com/science/article/pii/S089360802100277X
# Processing link: https://www.sciencedirect.com/science/article/pii/S0957417425019128
# Processing link: https://www.sciencedirect.com/science/article/pii/S2590005624000341
# Processing link: https://www.sciencedirect.com/science/article/pii/S0950705123001661
# Processing link: https://www.sciencedirect.com/science/article/pii/S1876380425605465
# Processing link: https://www.sciencedirect.com/science/article/pii/S0950705125000942
# Processing link: https://www.sciencedirect.com/science/article/pii/S1438887124007222
# Processing link: https://www.sciencedirect.com/science/article/pii/S095070512300014X
# Processing link: https://www.sciencedirect.com/science/article/pii/S1877050924021860
# Processing link: https://www.sciencedirect.com/science/article/pii/S2666827025000246
# Processing link: https://www.sciencedirect.com/science/article/pii/S1084804525001286
# Processing link: https://www.sciencedirect.com/science/article/pii/S1532046424000674
# Processing link: https://www.sciencedirect.com/science/article/pii/S1568494624005921
# Processing link: https://www.sciencedirect.com/science/article/pii/S0957417423008850
# Processing link: https://www.sciencedirect.com/science/article/pii/S1570826824000441
# Processing link: https://www.sciencedirect.com/science/article/pii/S2291969425000547
# Processing link: https://www.sciencedirect.com/science/article/pii/S0957417425018822
# Processing link: https://www.sciencedirect.com/science/article/pii/S0957417424019572
# Processing link: https://www.sciencedirect.com/science/article/pii/S266682702500060X
# Processing link: https://www.sciencedirect.com/science/article/pii/S0022283625000798
# Processing link: https://www.sciencedirect.com/science/article/pii/S2665963822000719
# Processing link: https://www.sciencedirect.com/science/article/pii/B9781555583354500191
# Error: 'NoneType' object has no attribute 'ele'
# Processing link: https://www.sciencedirect.com/science/article/pii/S0926580523001620
# Processing link: https://www.sciencedirect.com/science/article/pii/B9781597497473000089
# Error: 'NoneType' object has no attribute 'ele'
# Processing link: https://www.sciencedirect.com/science/article/pii/B9780128043998000107
# Processing link: https://www.sciencedirect.com/science/article/pii/S0306457316305118
# Processing link: https://www.sciencedirect.com/science/article/pii/S2351978917305279
# Processing link: https://www.sciencedirect.com/science/article/pii/B9781558604568500308
# Error: 'NoneType' object has no attribute 'ele'
# Processing link: https://www.sciencedirect.com/science/article/pii/B9780123756978500030
# Processing link: https://www.sciencedirect.com/science/article/pii/S0306457325001001
# Processing link: https://www.sciencedirect.com/science/article/pii/S1226798824040868
# Processing link: https://www.sciencedirect.com/science/article/pii/B9780120884698501509
# Processing link: https://www.sciencedirect.com/science/article/pii/S2291969421000272
# Processing link: https://www.sciencedirect.com/science/article/pii/S1877050918315114
# Processing link: https://www.sciencedirect.com/science/article/pii/S2212827121000676
# Processing link: https://www.sciencedirect.com/science/article/pii/S0885230820301182
# Processing link: https://www.sciencedirect.com/science/article/pii/S1877050924026036
# Processing link: https://www.sciencedirect.com/science/article/pii/S2949719123000456
# Processing link: https://www.sciencedirect.com/science/article/pii/B9780128029640000040
# Processing link: https://www.sciencedirect.com/science/article/pii/S1532046419302126
# Processing link: https://www.sciencedirect.com/science/article/pii/S0950584925000138
# Processing link: https://www.sciencedirect.com/science/article/pii/S0160791X24003567
# Processing link: https://www.sciencedirect.com/science/article/pii/S0950584924000557
# Processing link: https://www.sciencedirect.com/science/article/pii/S0950705124000182
# Processing link: https://www.sciencedirect.com/science/article/pii/S2772442522000016
# Processing link: https://www.sciencedirect.com/science/article/pii/S0925231221003556
# Processing link: https://www.sciencedirect.com/science/article/pii/S0360131515000536
# Processing link: https://www.sciencedirect.com/science/article/pii/S0167404824004565
# Processing link: https://www.sciencedirect.com/science/article/pii/B9781555583293500248
# Processing link: https://www.sciencedirect.com/science/article/pii/S0950705123007384
# Processing link: https://www.sciencedirect.com/science/article/pii/B9781555583231500036
# Processing link: https://www.sciencedirect.com/science/article/pii/089561119190006H
# Processing link: https://www.sciencedirect.com/science/article/pii/S0065245817300347
# Processing link: https://www.sciencedirect.com/science/article/pii/S1876380424605240
# Processing link: https://www.sciencedirect.com/science/article/pii/S2590177X20300081
# Processing link: https://www.sciencedirect.com/science/article/pii/B9781558606777500043
# Processing link: https://www.sciencedirect.com/science/article/pii/S002002550200172X
# Processing link: https://www.sciencedirect.com/science/article/pii/B9780121680305500127
# Processing link: https://www.sciencedirect.com/science/article/pii/B9780123814142000099
# Processing link: https://www.sciencedirect.com/science/article/pii/S0306437921000211
# Processing link: https://www.sciencedirect.com/science/article/pii/B9781597494243000086
# Processing link: https://www.sciencedirect.com/science/article/pii/B9781597491761500072
# Processing link: https://www.sciencedirect.com/science/article/pii/S0306437914001823
# Processing link: https://www.sciencedirect.com/science/article/pii/S0164121208000836
# Processing link: https://www.sciencedirect.com/science/article/pii/S0306261924024437
# Processing link: https://www.sciencedirect.com/science/article/pii/B9781931836364500154
# Processing link: https://www.sciencedirect.com/science/article/pii/B9781597499637000086
# Error: 'NoneType' object has no attribute 'ele'
# Processing link: https://www.sciencedirect.com/science/article/pii/B9781597494243000037
# Processing link: https://www.sciencedirect.com/science/article/pii/S0306437906000809
# Processing link: https://www.sciencedirect.com/science/article/pii/B9781558604568500205
# Processing link: https://www.sciencedirect.com/science/article/pii/S0306437999000022
# Processing link: https://www.sciencedirect.com/science/article/pii/B9781931836043500126
# Processing link: https://www.sciencedirect.com/science/article/pii/B9781597499637000037
# Error: 'NoneType' object has no attribute 'ele'
# Processing link: https://www.sciencedirect.com/science/article/pii/S0950705118305549
# Processing link: https://www.sciencedirect.com/science/article/pii/S0169023X16301835
# Processing link: https://www.sciencedirect.com/science/article/pii/S2667345225000082
# Processing link: https://www.sciencedirect.com/science/article/pii/B9781555583293500078
# Processing link: https://www.sciencedirect.com/science/article/pii/B9780128042786000033
# Processing link: https://www.sciencedirect.com/science/article/pii/B9780443288241504646
# Processing link: https://www.sciencedirect.com/science/article/pii/S0950705124013522
# Processing link: https://www.sciencedirect.com/science/article/pii/S2214579621001210
# Processing link: https://www.sciencedirect.com/science/article/pii/S1877050925019088
# Processing link: https://www.sciencedirect.com/science/article/pii/B9780323901185000084
# Processing link: https://www.sciencedirect.com/science/article/pii/S2468502X24000160
# Processing link: https://www.sciencedirect.com/science/article/pii/B9780323901185000163
# Error: 'NoneType' object has no attribute 'ele'
# Processing link: https://www.sciencedirect.com/science/article/pii/S0925231224005666
# Processing link: https://www.sciencedirect.com/science/article/pii/S0925231225010677
# Processing link: https://www.sciencedirect.com/science/article/pii/S027861252500038X
# Processing link: https://www.sciencedirect.com/science/article/pii/S2666651022000249
# Processing link: https://www.sciencedirect.com/science/article/pii/S0378778825002452
# Processing link: https://www.sciencedirect.com/science/article/pii/S2665963821000063
# Processing link: https://www.sciencedirect.com/science/article/pii/S0925231224009251
# Processing link: https://www.sciencedirect.com/science/article/pii/S0004370224001930
# Processing link: https://www.sciencedirect.com/science/article/pii/S2949820124000870
# Processing link: https://www.sciencedirect.com/science/article/pii/S1877050923001552
# Processing link: https://www.sciencedirect.com/science/article/pii/S0169023X04002198
# Processing link: https://www.sciencedirect.com/science/article/pii/S1438887120007049
# Processing link: https://www.sciencedirect.com/science/article/pii/S2291969422002009
# Processing link: https://www.sciencedirect.com/science/article/pii/0003687089900732
# Processing link: https://www.sciencedirect.com/science/article/pii/S0306437904000936
# Processing link: https://www.sciencedirect.com/science/article/pii/S0933365725000016
# Processing link: https://www.sciencedirect.com/science/article/pii/S0306437923000637
# Processing link: https://www.sciencedirect.com/science/article/pii/B9780934613538500297
# Processing link: https://www.sciencedirect.com/science/article/pii/S1570826820300305
# Processing link: https://www.sciencedirect.com/science/article/pii/002073739290041I
# Processing link: https://www.sciencedirect.com/science/article/pii/B9781928994190500117
# Error: 'NoneType' object has no attribute 'ele'
# Processing link: https://www.sciencedirect.com/science/article/pii/S2949719123000109
# Processing link: https://www.sciencedirect.com/science/article/pii/S0957417423023710
# Processing link: https://www.sciencedirect.com/science/article/pii/S0957417421001536
# Processing link: https://www.sciencedirect.com/science/article/pii/S2590188520300032
# Processing link: https://www.sciencedirect.com/science/article/pii/095219769390015P
# Processing link: https://www.sciencedirect.com/science/article/pii/S0950584906000814
# All paper details extracted.
